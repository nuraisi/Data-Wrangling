# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/housePrice.csv")
df.head(5)
# Out:
#   Area  Room  Parking  Warehouse  Elevator         Address         Price  \
# 0   63     1     True       True      True         Shahran  1.850000e+09
# 1   60     1     True       True      True         Shahran  1.850000e+09
# 2   79     2     True       True      True          Pardis  5.500000e+08
# 3   95     2     True       True      True   Shahrake Qods  9.025000e+08
# 4  123     2     True       True      True  Shahrake Gharb  7.000000e+09
#
#    Price(USD)
# 0    61666.67
# 1    61666.67
# 2    18333.33
# 3    30083.33
# 4   233333.33

# %%
df = df.shape
df
# Out:
# (3479, 8)

# %%
df = df.dtypes
df
# Out:
# Area           object
# Room            int64
# Parking          bool
# Warehouse        bool
# Elevator         bool
# Address        object
# Price         float64
# Price(USD)    float64
# dtype: object

# %%
df['Area'] = df['Area'].replace({',': ''}, regex=True)
df['Area'] = df['Area'].astype(int)

# %%
df = df.dtypes
df
# Out:
# Area            int64
# Room            int64
# Parking          bool
# Warehouse        bool
# Elevator         bool
# Address        object
# Price         float64
# Price(USD)    float64
# dtype: object

# %%
columns = df.columns.tolist()
columns.pop(columns.index("Address"))
columns.insert(0, "Address")
df = df[columns]
df.head(5)
# Out:
#           Address Area  Room  Parking  Warehouse  Elevator         Price  \
# 0         Shahran   63     1     True       True      True  1.850000e+09
# 1         Shahran   60     1     True       True      True  1.850000e+09
# 2          Pardis   79     2     True       True      True  5.500000e+08
# 3   Shahrake Qods   95     2     True       True      True  9.025000e+08
# 4  Shahrake Gharb  123     2     True       True      True  7.000000e+09
#
#    Price(USD)
# 0    61666.67
# 1    61666.67
# 2    18333.33
# 3    30083.33
# 4   233333.33

# %%
columns = df.columns.tolist()
columns.pop(columns.index("Price(USD)"))
columns.insert(6, "Price(USD)")
df = df[columns]
df.head(5)
# Out:
#           Address Area  Room  Parking  Warehouse  Elevator  Price(USD)  \
# 0         Shahran   63     1     True       True      True    61666.67
# 1         Shahran   60     1     True       True      True    61666.67
# 2          Pardis   79     2     True       True      True    18333.33
# 3   Shahrake Qods   95     2     True       True      True    30083.33
# 4  Shahrake Gharb  123     2     True       True      True   233333.33
#
#           Price
# 0  1.850000e+09
# 1  1.850000e+09
# 2  5.500000e+08
# 3  9.025000e+08
# 4  7.000000e+09

# %%
df = df.rename(columns = {"Price" : "Price(Toman)"})
df.head(5)
# Out:
#           Address Area  Room  Parking  Warehouse  Elevator  Price(USD)  \
# 0         Shahran   63     1     True       True      True    61666.67
# 1         Shahran   60     1     True       True      True    61666.67
# 2          Pardis   79     2     True       True      True    18333.33
# 3   Shahrake Qods   95     2     True       True      True    30083.33
# 4  Shahrake Gharb  123     2     True       True      True   233333.33
#
#    Price(Toman)
# 0  1.850000e+09
# 1  1.850000e+09
# 2  5.500000e+08
# 3  9.025000e+08
# 4  7.000000e+09

# %%
df = df.sort_values(by = "Address")
df.head(5)
# Out:
#      Address Area  Room  Parking  Warehouse  Elevator  Price(USD)  \
# 1471  Abazar   88     2     True       True      True   186666.67
# 2877  Abazar   80     2     True       True      True   100000.00
# 370   Abazar   79     2     True       True      True   100000.00
# 1037  Abazar   95     2     True       True      True   223333.33
# 3397  Abazar   72     2     True       True      True   111666.67
#
#       Price(Toman)
# 1471  5.600000e+09
# 2877  3.000000e+09
# 370   3.000000e+09
# 1037  6.700000e+09
# 3397  3.350000e+09

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# Address         23
# Area             0
# Room             0
# Parking          0
# Warehouse        0
# Elevator         0
# Price(USD)       0
# Price(Toman)     0
# dtype: int64

# %%
df = df.dropna(subset=["Address"])
null_counts = df.isnull().sum()
null_counts
# Out:
# Address         0
# Area            0
# Room            0
# Parking         0
# Warehouse       0
# Elevator        0
# Price(USD)      0
# Price(Toman)    0
# dtype: int64

# %%
df = df.shape
df
# Out:
# (3456, 8)

# %%
fig, ax = plt.subplots(figsize=(5, 6))

ax.hist(df['Room'].dropna(), bins=10, color='salmon', edgecolor='black')
ax.set_title('Distribution of Rooms')
ax.set_xlabel('Number of Rooms')
ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()
